# %%
#%pip install tensorflow==2.11.*

# %%
#%pip install -q -U keras-tuner
#%pip install scikeras

# %%
#compatibility check
import sys
print(sys.version)
import pip
print(pip.__version__)
# Out:
# 3.9.13 (main, Oct 13 2022, 16:12:30)
# [Clang 12.0.0 ]
# 22.3.1

# %%
#necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import keras_tuner as kt

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder

from datetime import datetime

# %%
#assert library import
assert pd.__version__ >= '1.0.0'
assert np.__version__ >= '1.0.0'
assert tf.__version__ >= '2.0.0'
assert plt
assert Sequential
assert Dense
assert Dropout
assert BatchNormalization
assert Adam
assert l2
assert train_test_split
assert LabelEncoder
assert kt
assert tf.__version__ >= "2.0.0"

# %%
#read csv
df = pd.read_csv('cleaned_data_final.csv')

# %%
#turn labels to 0 and 1s
df['radiant_win'] = df['radiant_win'].replace({True: 1, False: 0})

# %% [markdown]
# Logistic Regression implemented with Keras

# %%
#train-test split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, 4:], df[['radiant_win']], test_size=0.2, random_state=42)

# %%
#convert numpy arrays of training to tensors, set to tf.float32
X_train_tensor = tf.convert_to_tensor(X_train.values, dtype=tf.float32)
X_test_tensor = tf.convert_to_tensor(X_test.values, dtype=tf.float32)
y_train_tensor = tf.convert_to_tensor(y_train.values, dtype=tf.float32)
y_test_tensor = tf.convert_to_tensor(y_test.values, dtype=tf.float32)

# %%
#hyperparameter tuning dictionary that will be searched on
params = {
    'learning_rate': [0.001, 0.01, 1.0],
    'activation': ['relu', 'sigmoid', 'tanh'],
    'regularization_strength': [0.01, 0.1]
}

# %%
#function to create logistic regression model:
def create_model(learning_rate=0.01, activation='relu', regularization_strength=0.01):
    model = Sequential()
    model.add(Dense(1, activation=activation, input_shape=(246,), kernel_regularizer=l2(regularization_strength)))
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model
#Wrapper
model = KerasClassifier(build_fn = create_model, verbose=0)
# Out:
# /var/folders/zr/l3b0jnnd4rs2n6yf0p7__f500000gn/T/ipykernel_3327/2431510573.py:9: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, verbose=0)

# %%
search= RandomizedSearchCV(estimator= model, param_distributions= params, cv=3, verbose=3)
search_result= search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END activation=relu, learning_rate=0.001, regularization_strength=0.1;, score=0.521 total time=   2.7s
# [CV 2/3] END activation=relu, learning_rate=0.001, regularization_strength=0.1;, score=0.522 total time=   2.3s
# [CV 3/3] END activation=relu, learning_rate=0.001, regularization_strength=0.1;, score=0.515 total time=   2.3s
# [CV 1/3] END activation=sigmoid, learning_rate=0.01, regularization_strength=0.01;, score=0.526 total time=   2.5s
# [CV 2/3] END activation=sigmoid, learning_rate=0.01, regularization_strength=0.01;, score=0.535 total time=   2.2s
# [CV 3/3] END activation=sigmoid, learning_rate=0.01, regularization_strength=0.01;, score=0.525 total time=   2.2s
# [CV 1/3] END activation=tanh, learning_rate=1.0, regularization_strength=0.01;, score=0.502 total time=   2.4s
# [CV 2/3] END activation=tanh, learning_rate=1.0, regularization_strength=0.01;, score=0.503 total time=   2.5s
# [CV 3/3] END activation=tanh, learning_rate=1.0, regularization_strength=0.01;, score=0.498 total time=   2.6s
# [CV 1/3] END activation=sigmoid, learning_rate=0.001, regularization_strength=0.01;, score=0.552 total time=   2.4s
# [CV 2/3] END activation=sigmoid, learning_rate=0.001, regularization_strength=0.01;, score=0.554 total time=   2.5s
# [CV 3/3] END activation=sigmoid, learning_rate=0.001, regularization_strength=0.01;, score=0.552 total time=   2.4s
# [CV 1/3] END activation=tanh, learning_rate=1.0, regularization_strength=0.1;, score=0.498 total time=   2.5s
# [CV 2/3] END activation=tanh, learning_rate=1.0, regularization_strength=0.1;, score=0.497 total time=   2.5s
# [CV 3/3] END activation=tanh, learning_rate=1.0, regularization_strength=0.1;, score=0.502 total time=   3.4s
# [CV 1/3] END activation=relu, learning_rate=0.001, regularization_strength=0.01;, score=0.529 total time=   2.7s
# [CV 2/3] END activation=relu, learning_rate=0.001, regularization_strength=0.01;, score=0.518 total time=   2.6s
# [CV 3/3] END activation=relu, learning_rate=0.001, regularization_strength=0.01;, score=0.509 total time=   2.4s
# [CV 1/3] END activation=tanh, learning_rate=0.01, regularization_strength=0.1;, score=0.518 total time=   2.4s
# [CV 2/3] END activation=tanh, learning_rate=0.01, regularization_strength=0.1;, score=0.525 total time=   2.5s
# [CV 3/3] END activation=tanh, learning_rate=0.01, regularization_strength=0.1;, score=0.525 total time=   2.4s
# [CV 1/3] END activation=tanh, learning_rate=0.01, regularization_strength=0.01;, score=0.528 total time=   2.2s
# [CV 2/3] END activation=tanh, learning_rate=0.01, regularization_strength=0.01;, score=0.531 total time=   2.3s
# [CV 3/3] END activation=tanh, learning_rate=0.01, regularization_strength=0.01;, score=0.523 total time=   2.4s
# [CV 1/3] END activation=tanh, learning_rate=0.001, regularization_strength=0.1;, score=0.519 total time=   2.3s
# [CV 2/3] END activation=tanh, learning_rate=0.001, regularization_strength=0.1;, score=0.523 total time=   2.3s
# [CV 3/3] END activation=tanh, learning_rate=0.001, regularization_strength=0.1;, score=0.511 total time=   2.4s
# [CV 1/3] END activation=relu, learning_rate=1.0, regularization_strength=0.01;, score=0.498 total time=   2.5s
# [CV 2/3] END activation=relu, learning_rate=1.0, regularization_strength=0.01;, score=0.497 total time=   3.8s
# [CV 3/3] END activation=relu, learning_rate=1.0, regularization_strength=0.01;, score=0.502 total time=   4.0s

# %%
print(search_result.best_params_)
# Out:
# {'regularization_strength': 0.01, 'learning_rate': 0.001, 'activation': 'sigmoid'}

# %%
#get best hyperparaeters
best_params = search_result.best_params_
#train LR with best parameters
model = create_model(learning_rate=best_params['learning_rate'],
                     activation=best_params['activation'], 
                     regularization_strength=best_params['regularization_strength'])

history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 2290/2290 [==============================] - 4s 1ms/step - loss: 0.6940 - accuracy: 0.5379 - val_loss: 0.6898 - val_accuracy: 0.5522
# Epoch 2/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5539 - val_loss: 0.6902 - val_accuracy: 0.5499
# Epoch 3/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5535 - val_loss: 0.6900 - val_accuracy: 0.5479
# Epoch 4/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5531 - val_loss: 0.6900 - val_accuracy: 0.5531
# Epoch 5/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5508 - val_loss: 0.6901 - val_accuracy: 0.5498
# Epoch 6/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5523 - val_loss: 0.6904 - val_accuracy: 0.5507
# Epoch 7/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5533 - val_loss: 0.6902 - val_accuracy: 0.5499
# Epoch 8/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5549 - val_loss: 0.6900 - val_accuracy: 0.5506
# Epoch 9/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5540 - val_loss: 0.6901 - val_accuracy: 0.5483
# Epoch 10/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5538 - val_loss: 0.6902 - val_accuracy: 0.5476
# Epoch 11/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5549 - val_loss: 0.6900 - val_accuracy: 0.5537
# Epoch 12/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5531 - val_loss: 0.6899 - val_accuracy: 0.5528
# Epoch 13/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5534 - val_loss: 0.6903 - val_accuracy: 0.5474
# Epoch 14/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5526 - val_loss: 0.6900 - val_accuracy: 0.5550
# Epoch 15/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5525 - val_loss: 0.6900 - val_accuracy: 0.5542
# Epoch 16/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5535 - val_loss: 0.6902 - val_accuracy: 0.5530
# Epoch 17/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5524 - val_loss: 0.6904 - val_accuracy: 0.5486
# Epoch 18/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5529 - val_loss: 0.6903 - val_accuracy: 0.5497
# Epoch 19/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5527 - val_loss: 0.6902 - val_accuracy: 0.5533
# Epoch 20/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6897 - accuracy: 0.5519 - val_loss: 0.6902 - val_accuracy: 0.5518
# Epoch 21/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5540 - val_loss: 0.6898 - val_accuracy: 0.5528
# Epoch 22/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5525 - val_loss: 0.6903 - val_accuracy: 0.5487
# Epoch 23/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5509 - val_loss: 0.6903 - val_accuracy: 0.5513
# Epoch 24/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5543 - val_loss: 0.6904 - val_accuracy: 0.5461
# Epoch 25/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5523 - val_loss: 0.6906 - val_accuracy: 0.5417
# Epoch 26/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5533 - val_loss: 0.6903 - val_accuracy: 0.5475
# Epoch 27/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5537 - val_loss: 0.6902 - val_accuracy: 0.5519
# Epoch 28/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5523 - val_loss: 0.6901 - val_accuracy: 0.5486
# Epoch 29/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5530 - val_loss: 0.6904 - val_accuracy: 0.5439
# Epoch 30/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5510 - val_loss: 0.6903 - val_accuracy: 0.5484
# Epoch 31/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5532 - val_loss: 0.6900 - val_accuracy: 0.5550
# Epoch 32/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5536 - val_loss: 0.6902 - val_accuracy: 0.5522
# Epoch 33/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5523 - val_loss: 0.6898 - val_accuracy: 0.5539
# Epoch 34/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5517 - val_loss: 0.6901 - val_accuracy: 0.5503
# Epoch 35/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5527 - val_loss: 0.6898 - val_accuracy: 0.5524
# Epoch 36/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5529 - val_loss: 0.6901 - val_accuracy: 0.5514
# Epoch 37/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5533 - val_loss: 0.6906 - val_accuracy: 0.5484
# Epoch 38/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5528 - val_loss: 0.6900 - val_accuracy: 0.5504
# Epoch 39/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5512 - val_loss: 0.6904 - val_accuracy: 0.5520
# Epoch 40/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5533 - val_loss: 0.6903 - val_accuracy: 0.5513
# Epoch 41/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5533 - val_loss: 0.6900 - val_accuracy: 0.5511
# Epoch 42/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5535 - val_loss: 0.6902 - val_accuracy: 0.5474
# Epoch 43/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5521 - val_loss: 0.6903 - val_accuracy: 0.5520
# Epoch 44/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5541 - val_loss: 0.6901 - val_accuracy: 0.5522
# Epoch 45/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5526 - val_loss: 0.6905 - val_accuracy: 0.5469
# Epoch 46/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5528 - val_loss: 0.6898 - val_accuracy: 0.5510
# Epoch 47/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5519 - val_loss: 0.6900 - val_accuracy: 0.5521
# Epoch 48/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5553 - val_loss: 0.6901 - val_accuracy: 0.5513
# Epoch 49/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5531 - val_loss: 0.6899 - val_accuracy: 0.5533
# Epoch 50/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5504 - val_loss: 0.6901 - val_accuracy: 0.5496
# Epoch 51/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5529 - val_loss: 0.6901 - val_accuracy: 0.5507
# Epoch 52/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5537 - val_loss: 0.6901 - val_accuracy: 0.5500
# Epoch 53/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5509 - val_loss: 0.6903 - val_accuracy: 0.5495
# Epoch 54/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5542 - val_loss: 0.6904 - val_accuracy: 0.5467
# Epoch 55/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5523 - val_loss: 0.6896 - val_accuracy: 0.5561
# Epoch 56/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5524 - val_loss: 0.6898 - val_accuracy: 0.5522
# Epoch 57/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5534 - val_loss: 0.6904 - val_accuracy: 0.5500
# Epoch 58/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5526 - val_loss: 0.6901 - val_accuracy: 0.5489
# Epoch 59/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5533 - val_loss: 0.6901 - val_accuracy: 0.5498
# Epoch 60/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5546 - val_loss: 0.6899 - val_accuracy: 0.5488
# Epoch 61/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5550 - val_loss: 0.6900 - val_accuracy: 0.5500
# Epoch 62/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5530 - val_loss: 0.6899 - val_accuracy: 0.5508
# Epoch 63/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5532 - val_loss: 0.6908 - val_accuracy: 0.5435
# Epoch 64/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5542 - val_loss: 0.6901 - val_accuracy: 0.5518
# Epoch 65/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5532 - val_loss: 0.6899 - val_accuracy: 0.5536
# Epoch 66/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5542 - val_loss: 0.6904 - val_accuracy: 0.5462
# Epoch 67/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6899 - accuracy: 0.5533 - val_loss: 0.6900 - val_accuracy: 0.5535
# Epoch 68/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5543 - val_loss: 0.6899 - val_accuracy: 0.5518
# Epoch 69/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5529 - val_loss: 0.6899 - val_accuracy: 0.5518
# Epoch 70/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5518 - val_loss: 0.6903 - val_accuracy: 0.5509
# Epoch 71/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5528 - val_loss: 0.6899 - val_accuracy: 0.5521
# Epoch 72/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5522 - val_loss: 0.6900 - val_accuracy: 0.5504
# Epoch 73/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5534 - val_loss: 0.6900 - val_accuracy: 0.5509
# Epoch 74/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5544 - val_loss: 0.6902 - val_accuracy: 0.5508
# Epoch 75/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5520 - val_loss: 0.6904 - val_accuracy: 0.5485
# Epoch 76/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5532 - val_loss: 0.6899 - val_accuracy: 0.5526
# Epoch 77/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5549 - val_loss: 0.6900 - val_accuracy: 0.5490
# Epoch 78/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5521 - val_loss: 0.6903 - val_accuracy: 0.5506
# Epoch 79/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5523 - val_loss: 0.6902 - val_accuracy: 0.5477
# Epoch 80/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5534 - val_loss: 0.6903 - val_accuracy: 0.5500
# Epoch 81/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5531 - val_loss: 0.6901 - val_accuracy: 0.5506
# Epoch 82/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5529 - val_loss: 0.6900 - val_accuracy: 0.5497
# Epoch 83/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5544 - val_loss: 0.6902 - val_accuracy: 0.5497
# Epoch 84/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5532 - val_loss: 0.6903 - val_accuracy: 0.5468
# Epoch 85/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5531 - val_loss: 0.6900 - val_accuracy: 0.5480
# Epoch 86/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5537 - val_loss: 0.6903 - val_accuracy: 0.5522
# Epoch 87/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5526 - val_loss: 0.6904 - val_accuracy: 0.5473
# Epoch 88/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5539 - val_loss: 0.6902 - val_accuracy: 0.5491
# Epoch 89/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5531 - val_loss: 0.6902 - val_accuracy: 0.5519
# Epoch 90/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5536 - val_loss: 0.6899 - val_accuracy: 0.5510
# Epoch 91/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5525 - val_loss: 0.6901 - val_accuracy: 0.5483
# Epoch 92/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6897 - accuracy: 0.5521 - val_loss: 0.6901 - val_accuracy: 0.5501
# Epoch 93/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5534 - val_loss: 0.6904 - val_accuracy: 0.5494
# Epoch 94/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5530 - val_loss: 0.6902 - val_accuracy: 0.5511
# Epoch 95/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5538 - val_loss: 0.6901 - val_accuracy: 0.5521
# Epoch 96/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5524 - val_loss: 0.6900 - val_accuracy: 0.5532
# Epoch 97/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.5531 - val_loss: 0.6901 - val_accuracy: 0.5506
# Epoch 98/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5532 - val_loss: 0.6899 - val_accuracy: 0.5538
# Epoch 99/100
# 2290/2290 [==============================] - 2s 1ms/step - loss: 0.6898 - accuracy: 0.5526 - val_loss: 0.6901 - val_accuracy: 0.5496
# Epoch 100/100
# 2290/2290 [==============================] - 3s 1ms/step - loss: 0.6898 - accuracy: 0.5536 - val_loss: 0.6899 - val_accuracy: 0.5515

# %%
#evaluate test accuracy
test_loss, test_acc = model.evaluate(X_test_tensor, y_test_tensor)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 573/573 [==============================] - 1s 830us/step - loss: 0.6899 - accuracy: 0.5515
# Test Loss: 0.6899
# Test Accuracy: 0.5515

# %%
#training loss plot
plt.plot(history.history['loss'])
plt.title('Logistic Regression-  Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

#training accuracy plot
plt.plot(history.history['accuracy'])
plt.title('Logistic Regression- Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, ConfusionMatrixDisplay, roc_curve, auc, RocCurveDisplay, PrecisionRecallDisplay
import seaborn as sns

def show_metrics(y_tr, y_te, yhat_tr, yhat_te, named):
    # accuracy scores for training and test sets
    acc_train = accuracy_score(y_tr, yhat_tr)
    acc_test = accuracy_score(y_te, yhat_te)

    print(f'training set accuracy (n={y_tr.shape[0]}): {acc_train:4.3f}')
    print(f'test set accuracy (n={y_te.shape[0]}): {acc_test:4.3f}')
    print()
    print('classificiation report on test set performance')
    print(classification_report(y_te, yhat_te))
    print()

    with sns.axes_style('white'):
        # confusion matrix
        ConfusionMatrixDisplay.from_predictions(y_te, yhat_te)
        plt.show()
        
        # roc-auc
        fpr, tpr, thresholds = roc_curve(y_te, yhat_te) 
        roc_auc = auc(fpr, tpr)
        roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                   estimator_name=named)
        roc_display.plot()
        plt.title('ROC Curve')
        plt.show()
        
        #precision recall curve
        PrecisionRecallDisplay.from_predictions(y_te, yhat_te, name=named)
        plt.show()

# %%
yhat_te_prob = model.predict(X_test)
yhat_te = (yhat_te_prob > 0.5).astype(int)
yhat_te

yhat_tr_prob = model.predict(X_train)
yhat_tr = (yhat_tr_prob > 0.5).astype(int)
yhat_tr
# Out:
# 573/573 [==============================] - 0s 698us/step
# 2290/2290 [==============================] - 2s 763us/step
# array([[0],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
show_metrics(y_train, y_test, yhat_tr, yhat_te, 'unscaled')
# Out:
# training set accuracy (n=73270): 0.558
# test set accuracy (n=18318): 0.551
#
# classificiation report on test set performance
#               precision    recall  f1-score   support
#
#            0       0.55      0.54      0.54      9062
#            1       0.56      0.57      0.56      9256
#
#     accuracy                           0.55     18318
#    macro avg       0.55      0.55      0.55     18318
# weighted avg       0.55      0.55      0.55     18318
